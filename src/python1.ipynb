# %%
c=3+4j
print(c)

# %%
print(5+10.86)#implicit type
print(5+10.86+1j)
print(5+10.86+1j+10)

a=int(10.3)
print(a)

from math import ceil
a=ceil(10.3)
print(a)
a=ceil(10.6)
print(a)

print(float(10))

# %%
print(5//2)
print(5/2)
print(5%2)
print(5**2)

# %%
n="hacking"
print(n)
n="b"+n[1:4]
print(n)
print(n[0])


s=""
for i in range(len(n)-1,-1,-1):
    s=s+n[i]
print(s)

a="abcd"
b=""
for i in range(len(a),0,-1):
    b=b+a[i-1]
print(b)

a="malayalam"
b=""
for i in range(len(a),0,-1):
    b=b+a[i-1]
if a==b:
    print("palindrome")
else:
    print("not palindrome")

# %%
name="jaya"
age=21
print("hello %s",name)
print("hello {} and age {}".format(name,age))
print(f"hello {name} and age {age}")

# %%
a="banana"
b={}
for ch in a:
    if ch not in b:
        b[ch] =1
    else:
        b[ch]+=1
print(b)

# %%
v="hello"
#s=list(v)
print("-".join(s))

# %%
v="hello"
d="olehl"

#if (frozenset(v)==frozenset(d)):
if (sorted(v)==sorted(d)):
    print("anagram")
else:
    print("not anagram")

# %%
s="apple"
v=s.upper()
print(s)
print(v)
